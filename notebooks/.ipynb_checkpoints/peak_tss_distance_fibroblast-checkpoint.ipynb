# %%
import numpy as np
import pandas as pd
# import jscatter
# import h5py
import os
import matplotlib.pylab as plt
import matplotlib.gridspec as gridspec
# import logomaker
import seaborn as sns
sns.set()

# %%
data_path = "/oak/stanford/groups/akundaje/atwang/gp_mouse_sc_analyses/results/assembly_2/mm10/peak_tss_distances/fibroblast/peak_data.tsv"

# %%
data = pd.read_csv(data_path, sep='\t', header=0)
data
# Out:
#        chr_x   start_x     end_x                   1  2_x 3_x      4_x  \
# 0       chr1   3100163   3100629      total_peak_167  131   .  4.28928
# 1       chr1   3119547   3120355     total_peak_168a  492   .  5.76340
# 2       chr1   3119547   3120355     total_peak_168b  735   .  7.22953
# 3       chr1   3120360   3120610      total_peak_169  350   .  4.79919
# 4       chr1   3121342   3121870     total_peak_170a  654   .  6.68317
# ...      ...       ...       ...                 ...  ...  ..      ...
# 191258  chrY  90838586  90839875  total_peak_210477b  179   .  2.61998
# 191259  chrY  90838586  90839875  total_peak_210477c  164   .  2.52519
# 191260  chrY  90838586  90839875  total_peak_210477d  838   .  5.28624
# 191261  chrY  90838586  90839875  total_peak_210477e  466   .  3.95675
# 191262  chrY  90841544  90841876   total_peak_210479  183   .  2.89764
#
#             5_x      6_x  summit_x  ...  xs.pos.pattern_42  xs.pos.pattern_5  \
# 0       13.1064  11.1800       203  ...                  0                 0
# 1       49.2829  46.9365       168  ...                  0                 0
# 2       73.5429  71.0421       507  ...                  0                 0
# 3       35.0483  32.8216       134  ...                  0                 0
# 4       65.4566  63.0021       202  ...                  0                 0
# ...         ...      ...       ...  ...                ...               ...
# 191258  17.9582  15.9429       533  ...                  0                 0
# 191259  16.4343  14.4449       635  ...                  0                 0
# 191260  83.8780  81.3241       870  ...                  0                 0
# 191261  46.6080  44.2817      1167  ...                  0                 0
# 191262  18.3943  16.3711       216  ...                  0                 0
#
#         xs.pos.pattern_6  xs.pos.pattern_7  xs.pos.pattern_8  \
# 0                      0                 0                 0
# 1                      0                 0                 0
# 2                      0                 0                 0
# 3                      0                 0                 0
# 4                      0                 0                 0
# ...                  ...               ...               ...
# 191258                 0                 0                 0
# 191259                 0                 0                 0
# 191260                 0                 0                 0
# 191261                 0                 0                 0
# 191262                 0                 0                 0
#
#         xs.pos.pattern_9  xs.neg.pattern_0  xs.neg.pattern_1  \
# 0                      0                 0                 0
# 1                      0                 0                 0
# 2                      0                 0                 0
# 3                      0                 0                 0
# 4                      0                 0                 0
# ...                  ...               ...               ...
# 191258                 0                 0                 0
# 191259                 0                 0                 0
# 191260                 0                 0                 0
# 191261                 0                 0                 0
# 191262                 0                 0                 0
#
#                       name  min_distance
# 0           total_peak_167          1001
# 1          total_peak_168a          1001
# 2          total_peak_168b          1001
# 3           total_peak_169          1001
# 4          total_peak_170a          1001
# ...                    ...           ...
# 191258  total_peak_210477b            57
# 191259  total_peak_210477c            45
# 191260  total_peak_210477d           280
# 191261  total_peak_210477e          1001
# 191262   total_peak_210479          1001
#
# [191263 rows x 151 columns]

# %%
import seaborn as sns
sns.set()

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(10, 5), dpi=200)

g = sns.scatterplot(data=data, x="diff_mean_qn", y="contrib_counts_e_dist", hue="min_distance", palette=sns.cubehelix_palette(as_cmap=True, reverse=True), s=3, edgecolor=None, alpha=0.4, ax=ax1)
g = sns.scatterplot(data=data, x="ss_mean", y="xs_mean", hue="min_distance", palette=sns.cubehelix_palette(as_cmap=True, reverse=True), s=3, edgecolor=None, alpha=0.4, ax=ax2)
# Out:
# /users/atwang/miniconda3/envs/gp_mouse_genome_transfer_notebooks/lib/python3.10/site-packages/IPython/core/events.py:93: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   func(*args, **kwargs)
# /users/atwang/miniconda3/envs/gp_mouse_genome_transfer_notebooks/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
def plot_pattern(pattern):
    fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(10, 5), dpi=200)

    g = sns.scatterplot(data=data, x="diff_mean_qn", y="contrib_counts_e_dist", hue=pattern, s=3, edgecolor=None, hue_norm=(0,2), alpha=0.6, ax=ax1)
    g = sns.scatterplot(data=data, x="ss_mean", y="xs_mean", hue=pattern, s=3, edgecolor=None, hue_norm=(0,2), alpha=0.6, ax=ax2)
