# %%
import numpy as np
import pandas as pd
import jscatter
import h5py
import os
import matplotlib.pylab as plt
import matplotlib.gridspec as gridspec
import logomaker
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
data_dir = "/oak/stanford/groups/akundaje/atwang/gp_mouse_sc_analyses/results/assembly_2/mm10/merge_peak_scores"
data_path = os.path.join(data_dir, "scores.tsv")
h5_path = "/oak/stanford/groups/akundaje/atwang/gp_mouse_sc_analyses/results/assembly_2/mm10/collate_peak_outputs/endothelial_cell/peak_outputs.h5"

# %%
h5_data = h5py.File(h5_path, 'r')
h5_data.keys()
# Out:
# <KeysViewHDF5 ['chr', 'end', 'mask', 'obs', 'peak_name', 'seqs', 'start', 'summit', 'tracks']>

# %%
data = pd.read_csv(data_path, sep='\t', header=0)
data
# Out:
#              chr_x  start_x    end_x                1    2_x 3_x       4_x  \
# 0             chr1  3121385  3121656   total_peak_193    455   .   4.26059
# 1             chr1  3670599  3672419  total_peak_195a   2121   .   6.46852
# 2             chr1  3670599  3672419  total_peak_195b   2112   .   6.45339
# 3             chr1  3670599  3672419  total_peak_195c   9047   .  15.64050
# 4             chr1  4205616  4206042   total_peak_196   1457   .   7.98861
# ...            ...      ...      ...              ...    ...  ..       ...
# 669433  JH584304.1   101687   101902   total_peak_129   1212   .   3.24063
# 669434  JH584304.1   103144   103422   total_peak_130   3552   .   5.33690
# 669435  JH584304.1   103769   104115   total_peak_131  15200   .  12.45700
# 669436  JH584304.1   104202   104357   total_peak_132   2185   .   4.17417
# 669437  JH584304.1   109058   109443   total_peak_133    324   .   2.65558
#
#              5_x        6_x  summit_x  ...  contrib_counts_nlq  \
# 0         45.595    43.6826       129  ...                 inf
# 1        212.130   209.8280       248  ...                 inf
# 2        211.276   208.9760       496  ...                 inf
# 3        904.732   901.8890      1143  ...                 inf
# 4        145.732   143.5400       176  ...                 inf
# ...          ...        ...       ...  ...                 ...
# 669433   121.231   118.4310       101  ...                 inf
# 669434   355.220   351.9000       164  ...                 inf
# 669435  1520.090  1514.5800       106  ...                 inf
# 669436   218.517   215.4580        81  ...                 inf
# 669437    32.449    30.1703       159  ...                 inf
#
#         contrib_counts_dist_pooled  ss_self_contrib_profiles_dist_mean  \
# 0                         0.346419                            0.304104
# 1                         0.361833                            0.363447
# 2                         0.371009                            0.366195
# 3                         0.365666                            0.363252
# 4                         0.353488                            0.550182
# ...                            ...                                 ...
# 669433                    0.957784                            1.061023
# 669434                    0.951562                            1.022063
# 669435                    0.905843                            0.952113
# 669436                    0.887472                            0.920010
# 669437                    0.976443                            1.111279
#
#         xs_self_contrib_profiles_dist_mean  cross_contrib_profiles_dist_mean  \
# 0                                 0.604295                          0.853306
# 1                                 0.343455                          0.438878
# 2                                 0.345950                          0.442376
# 3                                 0.343145                          0.438088
# 4                                 0.486106                          0.693349
# ...                                    ...                               ...
# 669433                            1.059249                          1.359916
# 669434                            1.003367                          1.344730
# 669435                            0.700033                          1.134917
# 669436                            0.668715                          1.107371
# 669437                            1.055973                          1.382676
#
#         contrib_profiles_e_dist  contrib_profiles_nlp  contrib_profiles_nlq  \
# 0                      0.893428                   inf                   inf
# 1                      0.413344                   inf                   inf
# 2                      0.415460                   inf                   inf
# 3                      0.412042                   inf                   inf
# 4                      0.591954                   inf                   inf
# ...                         ...                   ...                   ...
# 669433                 0.774313                   inf                   inf
# 669434                 0.814881                   inf                   inf
# 669435                 0.785931              2.100371              2.087146
# 669436                 0.791213              2.100371              2.087146
# 669437                 0.773369                   inf                   inf
#
#         contrib_profiles_dist_pooled             Label
# 0                           0.744118     cardiomyocyte
# 1                           0.198070     cardiomyocyte
# 2                           0.199828     cardiomyocyte
# 3                           0.196640     cardiomyocyte
# 4                           0.408786     cardiomyocyte
# ...                              ...               ...
# 669433                      1.253101  endothelial_cell
# 669434                      1.233920  endothelial_cell
# 669435                      0.830480  endothelial_cell
# 669436                      0.807376  endothelial_cell
# 669437                      1.425392  endothelial_cell
#
# [669438 rows x 63 columns]

# %%
# num_peaks = h5_data['chr'].shape[0]
# h5_ind_map = {(chr.decode(), summit): ind for chr, summit, ind in zip(h5_data["chr"], h5_data["summit"], range(num_peaks))}
h5_ind_map = {name.decode(): ind for ind, name in enumerate(h5_data["peak_name"])}

# list(h5_ind_map.keys())[0]

# %%
data_endo = data[data["Label"] == "endothelial_cell"]
data_endo
# Out:
#              chr_x  start_x    end_x                1    2_x 3_x       4_x  \
# 509735        chr1  3121337  3121796   total_peak_140    588   .  12.41760
# 509736        chr1  3191533  3192041  total_peak_141a     36   .   2.48353
# 509737        chr1  3191533  3192041  total_peak_141b    335   .   8.60956
# 509738        chr1  3360964  3361276   total_peak_143    119   .   4.63592
# 509739        chr1  3670569  3670973   total_peak_146    394   .   7.10173
# ...            ...      ...      ...              ...    ...  ..       ...
# 669433  JH584304.1   101687   101902   total_peak_129   1212   .   3.24063
# 669434  JH584304.1   103144   103422   total_peak_130   3552   .   5.33690
# 669435  JH584304.1   103769   104115   total_peak_131  15200   .  12.45700
# 669436  JH584304.1   104202   104357   total_peak_132   2185   .   4.17417
# 669437  JH584304.1   109058   109443   total_peak_133    324   .   2.65558
#
#                5_x         6_x  summit_x  ...  contrib_counts_nlq  \
# 509735    58.87260    56.37410       229  ...                 inf
# 509736     3.60957     1.94164       119  ...                 inf
# 509737    33.52660    31.23600       348  ...                 inf
# 509738    11.92300     9.94400       108  ...                 inf
# 509739    39.47270    37.12530       260  ...                 inf
# ...            ...         ...       ...  ...                 ...
# 669433   121.23100   118.43100       101  ...                 inf
# 669434   355.22000   351.90000       164  ...                 inf
# 669435  1520.09000  1514.58000       106  ...                 inf
# 669436   218.51700   215.45800        81  ...                 inf
# 669437    32.44900    30.17030       159  ...                 inf
#
#         contrib_counts_dist_pooled  ss_self_contrib_profiles_dist_mean  \
# 509735                    0.323075                            0.311307
# 509736                    1.005719                            0.661089
# 509737                    1.005663                            0.661111
# 509738                    0.579914                            0.361556
# 509739                    0.449046                            0.502111
# ...                            ...                                 ...
# 669433                    0.957784                            1.061023
# 669434                    0.951562                            1.022063
# 669435                    0.905843                            0.952113
# 669436                    0.887472                            0.920010
# 669437                    0.976443                            1.111279
#
#         xs_self_contrib_profiles_dist_mean  cross_contrib_profiles_dist_mean  \
# 509735                            0.335871                          0.416471
# 509736                            1.049390                          1.383903
# 509737                            1.049379                          1.383875
# 509738                            0.658825                          0.990510
# 509739                            0.443025                          1.056293
# ...                                    ...                               ...
# 669433                            1.059249                          1.359916
# 669434                            1.003367                          1.344730
# 669435                            0.700033                          1.134917
# 669436                            0.668715                          1.107371
# 669437                            1.055973                          1.382676
#
#         contrib_profiles_e_dist  contrib_profiles_nlp  contrib_profiles_nlq  \
# 509735                 0.431004                   inf                   inf
# 509736                 1.028264              2.100371              2.084357
# 509737                 1.028232              2.100371              2.084357
# 509738                 0.980122                   inf                   inf
# 509739                 1.080487              2.100371              2.084357
# ...                         ...                   ...                   ...
# 669433                 0.774313                   inf                   inf
# 669434                 0.814881                   inf                   inf
# 669435                 0.785931              2.100371              2.087146
# 669436                 0.791213              2.100371              2.087146
# 669437                 0.773369                   inf                   inf
#
#         contrib_profiles_dist_pooled             Label
# 509735                      0.218467  endothelial_cell
# 509736                      1.454968  endothelial_cell
# 509737                      1.454880  endothelial_cell
# 509738                      0.905201  endothelial_cell
# 509739                      1.060347  endothelial_cell
# ...                              ...               ...
# 669433                      1.253101  endothelial_cell
# 669434                      1.233920  endothelial_cell
# 669435                      0.830480  endothelial_cell
# 669436                      0.807376  endothelial_cell
# 669437                      1.425392  endothelial_cell
#
# [159703 rows x 63 columns]

# %%
h5_inds = [h5_ind_map[r["1"]] for _, r in data_endo.iterrows()]
h5_inds[:5]
# Out:
# [0, 1, 2, 3, 4]

# %%
def plot_contribs(track, seq, ax):
    contribs = track[:,None] * seq
    df = pd.DataFrame(contribs, columns = ['A','C','G','T'])
    logomaker.Logo(df, ax=ax)

def plot_count_tracks(h5_data, idx):
    x = list(range(2114))
    tracks = h5_data["tracks"]
    seq = h5_data["seqs"][idx]

    gs = gridspec.GridSpec(21,1)
    fig = plt.figure(figsize=(30, 15), dpi=200)

    ax = fig.add_subplot(gs[0])
    # print(h5_data["obs"][idx,:])
    ax.plot(x, h5_data["obs"][idx,:])

    ax = fig.add_subplot(gs[1], sharex=ax)
    # print(h5_data["tracks"][idx,2,0,:])
    ax.plot(x, tracks[idx,0,0,:])
    ax = fig.add_subplot(gs[2], sharex=ax)
    ax.plot(x, tracks[idx,0,1,:])
    ax = fig.add_subplot(gs[3], sharex=ax)
    ax.plot(x, tracks[idx,0,2,:])
    ax = fig.add_subplot(gs[4], sharex=ax)
    ax.plot(x, tracks[idx,0,3,:])
    ax = fig.add_subplot(gs[5], sharex=ax)
    ax.plot(x, tracks[idx,0,4,:])

    ax = fig.add_subplot(gs[6], sharex=ax)
    plot_contribs(tracks[idx,4,0,:], seq, ax)
    ax = fig.add_subplot(gs[7], sharex=ax)
    plot_contribs(tracks[idx,4,1,:], seq, ax)
    ax = fig.add_subplot(gs[8], sharex=ax)
    plot_contribs(tracks[idx,4,2,:], seq, ax)
    ax = fig.add_subplot(gs[9], sharex=ax)
    plot_contribs(tracks[idx,4,3,:], seq, ax)
    ax = fig.add_subplot(gs[10], sharex=ax)
    plot_contribs(tracks[idx,4,4,:], seq, ax)
    
    ax = fig.add_subplot(gs[11], sharex=ax)
    ax.plot(x, tracks[idx,1,0,:])
    ax = fig.add_subplot(gs[12], sharex=ax)
    ax.plot(x, tracks[idx,1,1,:])
    ax = fig.add_subplot(gs[13], sharex=ax)
    ax.plot(x, tracks[idx,1,2,:])
    ax = fig.add_subplot(gs[14], sharex=ax)
    ax.plot(x, tracks[idx,1,3,:])
    ax = fig.add_subplot(gs[15], sharex=ax)
    ax.plot(x, tracks[idx,1,4,:])
    
    ax = fig.add_subplot(gs[16], sharex=ax)
    plot_contribs(tracks[idx,5,0,:], seq, ax)
    ax = fig.add_subplot(gs[17], sharex=ax)
    plot_contribs(tracks[idx,5,1,:], seq, ax)
    ax = fig.add_subplot(gs[18], sharex=ax)
    plot_contribs(tracks[idx,5,2,:], seq, ax)
    ax = fig.add_subplot(gs[19], sharex=ax)
    plot_contribs(tracks[idx,5,3,:], seq, ax)
    ax = fig.add_subplot(gs[20], sharex=ax)
    plot_contribs(tracks[idx,5,4,:], seq, ax)

    plt.tick_params(
        axis='x',          # changes apply to the x-axis
        labelbottom='off')

    plt.show()

# %%
# plot_count_tracks(h5_data, h5_inds[0])

# %%
s2 = jscatter.Scatter(data=data_endo, x="ss_mean", y="xs_mean", color_by="contrib_counts_e_dist", height=480)
s = jscatter.Scatter(data=data_endo, x="diff_mean_qn", y="contrib_counts_e_dist", color_by="-log10p_qn", height=480)

jscatter.link([
    s, s2
])
# s.show()
# Out:
# GridBox(children=(HBox(children=(VBox(children=(Button(button_style='primary', icon='arrows', layout=Layout(wi…

# %%
sel = s.selection()
sel_data = data_endo.iloc[sel]
sel_data
# Out:
#         chr_x   start_x     end_x                   1  2_x 3_x       4_x  \
# 576585  chr17  49916856  49917087    total_peak_75700  158   .   5.46376
# 522500  chr10  41847773  41848563   total_peak_15369a  427   .   9.61832
# 535721  chr11  94127850  94128303   total_peak_29909a   65   .   2.36058
# 630868   chr6  28929133  28929752  total_peak_137021a  658   .   6.72813
# 581982  chr18  46438917  46439128    total_peak_81850  111   .   4.47035
# ...       ...       ...       ...                 ...  ...  ..       ...
# 630020   chr6   4762368   4762611   total_peak_135969  530   .  11.58980
# 631416   chr6  34331376  34331871   total_peak_137672  366   .   9.10627
# 567194  chr16   4743003   4743295    total_peak_65236   57   .   3.10711
# 584939  chr19   3656285   3656727    total_peak_85323  450   .   4.42564
# 620640   chr5  13871396  13871737  total_peak_125155b  134   .   4.96705
#
#              5_x       6_x  summit_x  ...  contrib_counts_nlq  \
# 576585  15.87850  13.82050       133  ...            2.100371
# 522500  42.77780  40.40140       183  ...            2.100371
# 535721   6.52148   4.70049        80  ...            2.100371
# 630868  65.81220  63.26900       218  ...            2.100371
# 581982  11.17510   9.21340       102  ...            2.100371
# ...          ...       ...       ...  ...                 ...
# 630020  53.06630  50.60840       125  ...            2.100371
# 631416  36.61880  34.29760       172  ...            2.100371
# 567194   5.71244   3.92927       112  ...            2.100327
# 584939  45.01440  42.61930       296  ...            2.100371
# 620640  13.46350  11.45150       227  ...            2.100371
#
#         contrib_counts_dist_pooled  ss_self_contrib_profiles_dist_mean  \
# 576585                    0.920339                            0.302723
# 522500                    1.027546                            0.533249
# 535721                    1.424943                            0.449313
# 630868                    1.263615                            0.683921
# 581982                    1.214317                            0.528453
# ...                            ...                                 ...
# 630020                    1.331927                            1.022993
# 631416                    1.202252                            0.508703
# 567194                    1.460485                            1.096947
# 584939                    1.136277                            0.779605
# 620640                    1.263246                            0.487353
#
#         xs_self_contrib_profiles_dist_mean  cross_contrib_profiles_dist_mean  \
# 576585                            0.595460                          1.268236
# 522500                            0.507814                          1.440664
# 535721                            0.569620                          1.382460
# 630868                            0.487020                          1.051385
# 581982                            0.441055                          1.230782
# ...                                    ...                               ...
# 630020                            0.582039                          1.241108
# 631416                            0.477356                          1.467216
# 567194                            0.376543                          1.281438
# 584939                            0.760087                          1.525669
# 620640                            0.868025                          1.448494
#
#         contrib_profiles_e_dist  contrib_profiles_nlp  contrib_profiles_nlq  \
# 576585                 1.279957              2.100371              2.085438
# 522500                 1.356563              2.100371              2.084448
# 535721                 1.321358              2.100371              2.085842
# 630868                 0.965313                   inf                   inf
# 581982                 1.221498              2.100371              2.084312
# ...                         ...                   ...                   ...
# 630020                 0.936581                   inf                   inf
# 631416                 1.395841              2.100371              2.084267
# 567194                 1.043736              2.100371              2.084312
# 584939                 1.229490              2.100371              2.084312
# 620640                 1.241616              2.100371              2.085393
#
#         contrib_profiles_dist_pooled             Label
# 576585                      1.345889  endothelial_cell
# 522500                      1.478617  endothelial_cell
# 535721                      1.404401  endothelial_cell
# 630868                      0.957437  endothelial_cell
# 581982                      1.220992  endothelial_cell
# ...                              ...               ...
# 630020                      1.138429  endothelial_cell
# 631416                      1.479038  endothelial_cell
# 567194                      1.060373  endothelial_cell
# 584939                      1.565284  endothelial_cell
# 620640                      1.482219  endothelial_cell
#
# [75 rows x 63 columns]

# %%
sel_inds = [h5_ind_map[r["1"]] for _, r in sel_data.iterrows()]

# %%
def dist_metric(a, b):
    a_normalized = a / np.sqrt((a**2).sum(axis=0, keepdims=True))
    b_normalized = b / np.sqrt((b**2).sum(axis=0, keepdims=True))
    dist = np.nan_to_num(np.sqrt(((a_normalized - b_normalized)**2).sum(axis=0)))
    return dist

def pairwise_dists(contribs_ss, contribs_xs):
    n_ss = contribs_ss.shape[0]
    n_xs = contribs_xs.shape[0]
    n = n_ss + n_xs

    all_data = np.concatenate((contribs_ss, contribs_xs), axis=0)

    ltri_dists = np.zeros((n, n),)
    for j in range(n):
        for i in range(j, n):
            a = all_data[i]
            b = all_data[j]
            dist = dist_metric(a, b)
            ltri_dists[i,j] = dist

    # print(ltri_dists.diagonal(axis1=1, axis2=2).mean()) ####
    # assert(ltri_dists.diagonal(axis1=1, axis2=2).sum() == 0)

    dists_all = ltri_dists + ltri_dists.transpose(1, 0)
    
    ss_self_dists = dists_all[:n_ss,:n_ss]
    xs_self_dists = dists_all[n_ss:n,n_ss:n]
    cross_dists = dists_all[:n_ss,n_ss:n]

    return dists_all, ss_self_dists, xs_self_dists, cross_dists

# %%
rnum = 0
idx = sel_inds[rnum]

# %%
dists_all, ss_self_dists, xs_self_dists, cross_dists = tracks = pairwise_dists(h5_data["tracks"][idx,4,:,:], h5_data["tracks"][idx,5,:,:])
print(ss_self_dists)
print(xs_self_dists)
print(cross_dists)
# Out:
# [[0.         0.54687893 0.64702481 0.48434854 0.59425277]
#  [0.54687893 0.         0.61750561 0.49310517 0.61934519]
#  [0.64702481 0.61750561 0.         0.71035635 0.7927497 ]
#  [0.48434854 0.49310517 0.71035635 0.         0.47229552]
#  [0.59425277 0.61934519 0.7927497  0.47229552 0.        ]]
# [[0.         0.42127189 0.493209   0.47788495 0.56709749]
#  [0.42127189 0.         0.46224815 0.48014429 0.60813147]
#  [0.493209   0.46224815 0.         0.52458411 0.67534673]
#  [0.47788495 0.48014429 0.52458411 0.         0.52918249]
#  [0.56709749 0.60813147 0.67534673 0.52918249 0.        ]]
# [[1.0634917  1.09472716 1.1645726  1.02805281 0.89202136]
#  [1.06127369 1.07855749 1.14063799 1.01106417 0.95387512]
#  [1.18650329 1.19859993 1.24077213 1.13657963 1.03925025]
#  [0.92134082 0.96732146 1.05225325 0.89179713 0.80224764]
#  [0.81429511 0.85492212 0.94286931 0.75625765 0.63851929]]

# %%
print(np.mean(ss_self_dists))
print(np.mean(xs_self_dists))
print(np.mean(cross_dists))
# Out:
# 0.4782290077209473
# 0.4191280460357666
# 0.9972721242904663

# %%
# a = h5_data["tracks"][idx,4,:,:] / h5_data["tracks"][idx,4,:,:].sum(axis=1, keepdims=True)
# b = h5_data["tracks"][idx,5,:,:] / h5_data["tracks"][idx,5,:,:].sum(axis=1, keepdims=True)
# dists_all, ss_self_dists, xs_self_dists, cross_dists = tracks = pairwise_dists(a, b)
# print(ss_self_dists)
# print(xs_self_dists)
# print(cross_dists)
# print(np.mean(ss_self_dists))
# print(np.mean(xs_self_dists))
# print(np.mean(cross_dists))

# %%
# print(sel_data.iloc[idx])
sel_data.iloc[rnum][["ss_self_contrib_counts_dist_mean", "xs_self_contrib_counts_dist_mean", "cross_contrib_counts_dist_mean"]]
# Out:
# ss_self_contrib_counts_dist_mean    0.478229
# xs_self_contrib_counts_dist_mean    0.419128
# cross_contrib_counts_dist_mean      0.997272
# Name: 576585, dtype: object

# %%
# print(sel_data.iloc[rnum]["ss_mean"], np.log1p(np.sum(h5_data["tracks"][idx,0,:,:], axis=1)).mean(axis=0), sel_data.iloc[rnum]["obs_logcounts"], np.log1p(np.sum(h5_data["obs"][idx,:], axis=0)))

# %%
plot_count_tracks(h5_data, idx)
